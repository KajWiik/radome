# %%
using Plots; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
plot(rand(2),rand(2),rand(2),color="red",leg=false)
plot!(rand(2),rand(2),rand(2),color="red",leg=false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(rand(5));plot!(rand(5))
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(rand(5))
plot!(rand(5))
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot!(rand(5))
# Out:
# <img src="data:image/png;base64,..." />
